# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt


import bokeh
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set(style="white", color_codes=True)

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "Resources/pollution_us_2000_2016.csv"
df = pd.read_csv(csv_path)

state_csv_path = "Resources/State_2016.csv"
state_2016_df = pd.read_csv(state_csv_path)

# %%
#pandas datetimeindex docs: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DatetimeIndex.html
#efficient way to extract year from string format date

df['year'] = pd.DatetimeIndex(df['Date Local']).year
df['month'] = pd.DatetimeIndex(df['Date Local']).month
df['Date Local'] = pd.to_datetime(df['Date Local'],format='%Y-%m-%d')

# %%
# Delete extraneous column
df = df.drop(['Unnamed: 0','State Code','County Code','Address','Site Num','NO2 Units','O3 Units','SO2 Units','CO Units'], axis=1)
# Removing Mexico
df = df[df.State!='Country Of Mexico']
df.head()
# Out:
#      State    County     City Date Local   NO2 Mean  NO2 1st Max Value  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 1  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 2  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 3  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 4  Arizona  Maricopa  Phoenix 2000-01-02  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI   O3 Mean  O3 1st Max Value  ...  SO2 Mean  \
# 0                19       46  0.022500             0.040  ...  3.000000
# 1                19       46  0.022500             0.040  ...  3.000000
# 2                19       46  0.022500             0.040  ...  2.975000
# 3                19       46  0.022500             0.040  ...  2.975000
# 4                19       34  0.013375             0.032  ...  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   CO Mean  CO 1st Max Value  \
# 0                9.0                21     13.0  1.145833               4.2
# 1                9.0                21     13.0  0.878947               2.2
# 2                6.6                23      NaN  1.145833               4.2
# 3                6.6                23      NaN  0.878947               2.2
# 4                3.0                22      4.0  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  year  month
# 0               21     NaN  2000      1
# 1               23    25.0  2000      1
# 2               21     NaN  2000      1
# 3               23    25.0  2000      1
# 4               23     NaN  2000      1
#
# [5 rows x 22 columns]

# %%
df.State.unique()
# Out:
# array(['Arizona', 'California', 'Colorado', 'District Of Columbia',
#        'Florida', 'Illinois', 'Indiana', 'Kansas', 'Kentucky',
#        'Louisiana', 'Michigan', 'Missouri', 'New Jersey', 'New York',
#        'North Carolina', 'Oklahoma', 'Pennsylvania', 'Texas', 'Virginia',
#        'Massachusetts', 'Nevada', 'New Hampshire', 'Tennessee',
#        'South Carolina', 'Connecticut', 'Iowa', 'Maine', 'Maryland',
#        'Wisconsin', 'Arkansas', 'Oregon', 'Wyoming', 'North Dakota',
#        'Idaho', 'Ohio', 'Georgia', 'Delaware', 'Hawaii', 'Minnesota',
#        'New Mexico', 'Rhode Island', 'South Dakota', 'Utah', 'Alabama',
#        'Washington', 'Alaska'], dtype=object)

# %%
df_grouped = df.groupby(['State','Date Local']).mean()
df_grouped.head()
# Out:
#                      NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# State   Date Local
# Alabama 2013-12-01  17.208333               39.3              18.0     37.0
#         2013-12-02  20.687500               32.4               7.0     30.0
#         2013-12-03  14.912500               22.4              17.0     21.0
#         2013-12-04   7.825000               19.3              17.0     18.0
#         2013-12-05   8.004762               16.0               7.0     15.0
#
#                      O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI  \
# State   Date Local
# Alabama 2013-12-01  0.013542             0.026              9.0    24.0
#         2013-12-02  0.009375             0.013              0.0    12.0
#         2013-12-03  0.008167             0.012             22.0    11.0
#         2013-12-04  0.011125             0.014              8.0    13.0
#         2013-12-05  0.010083             0.014             18.0    13.0
#
#                     SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI  \
# State   Date Local
# Alabama 2013-12-01  0.285390               0.75              11.0      1.0
#         2013-12-02  0.531666               2.10              11.0      3.0
#         2013-12-03  0.252632               1.35              12.5      3.0
#         2013-12-04  0.123052               0.95              17.0      1.0
#         2013-12-05 -0.014285               0.60               2.5      1.0
#
#                      CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI  \
# State   Date Local
# Alabama 2013-12-01  0.262879             0.650              8.5     6.0
#         2013-12-02  0.352812             0.485              8.0     6.0
#         2013-12-03  0.237575             0.325              4.0     3.0
#         2013-12-04  0.115152             0.220             18.5     2.0
#         2013-12-05  0.117575             0.200             17.5     2.0
#
#                       year  month
# State   Date Local
# Alabama 2013-12-01  2013.0   12.0
#         2013-12-02  2013.0   12.0
#         2013-12-03  2013.0   12.0
#         2013-12-04  2013.0   12.0
#         2013-12-05  2013.0   12.0

# %%
#NO2 data
NO2_data = df[["State","Date Local","NO2 Mean","NO2 1st Max Value", "NO2 1st Max Hour", "NO2 AQI","year"
                          ]]
NO2_data.head()
# Out:
#      State Date Local   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  \
# 0  Arizona 2000-01-01  19.041667               49.0                19
# 1  Arizona 2000-01-01  19.041667               49.0                19
# 2  Arizona 2000-01-01  19.041667               49.0                19
# 3  Arizona 2000-01-01  19.041667               49.0                19
# 4  Arizona 2000-01-02  22.958333               36.0                19
#
#    NO2 AQI  year
# 0       46  2000
# 1       46  2000
# 2       46  2000
# 3       46  2000
# 4       34  2000

# %%
df_c = NO2_data.sort_values('State')
df_c = NO2_data.sort_values('NO2 Mean')
df_c.head()
# Out:
#             State Date Local  NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  \
# 1294684  Oklahoma 2012-05-29      -2.0               -2.0                 0
# 1294686  Oklahoma 2012-05-29      -2.0               -2.0                 0
# 1294687  Oklahoma 2012-05-29      -2.0               -2.0                 0
# 1294683  Oklahoma 2012-05-28      -2.0               -2.0                 0
# 1294682  Oklahoma 2012-05-28      -2.0               -2.0                 0
#
#          NO2 AQI  year
# 1294684        0  2012
# 1294686        0  2012
# 1294687        0  2012
# 1294683        0  2012
# 1294682        0  2012

# %%
#Mean NO2 levels for each state
ax = sns.barplot(x="NO2 Mean",y="State", data=df_c, ci=100)
#ax = sns.sort_values(by='NO2 Mean',ascending=False)
fig = plt.gcf()
fig.set_size_inches(30, 13)

plt.title("Mean NO2 levels for each state")

# Save figure with the parameter bbox_inches to fit the whole image
plt.savefig("ImagesQ1/NO2_Levels_For_Each_State.png", bbox_inches="tight")

# %%
#O3 data

O3_data = df[["State", "County", "City","O3 Mean","O3 1st Max Value", "O3 1st Max Hour", "O3 AQI"
                          ]]
O3_data.head()
# Out:
#      State    County     City   O3 Mean  O3 1st Max Value  O3 1st Max Hour  \
# 0  Arizona  Maricopa  Phoenix  0.022500             0.040               10
# 1  Arizona  Maricopa  Phoenix  0.022500             0.040               10
# 2  Arizona  Maricopa  Phoenix  0.022500             0.040               10
# 3  Arizona  Maricopa  Phoenix  0.022500             0.040               10
# 4  Arizona  Maricopa  Phoenix  0.013375             0.032               10
#
#    O3 AQI
# 0      34
# 1      34
# 2      34
# 3      34
# 4      27

# %%
#Mean O3 levels for each state
ax = sns.barplot(x="O3 Mean",y="State", data=O3_data, ci=100)
fig = plt.gcf()
fig.set_size_inches(18, 13)


plt.title("Mean O3 levels for each state")

plt.savefig("ImagesQ1/O3_Levels_For_Each_State.png", bbox_inches="tight")

plt.show()

# %%
#SO2 data
SO2_data = df[["State","County", "City","SO2 Mean","SO2 1st Max Value", "SO2 1st Max Hour", "SO2 AQI","Date Local","year"
                   ]]
SO2_data.head()
# Out:
#      State    County     City  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# 0  Arizona  Maricopa  Phoenix  3.000000                9.0                21
# 1  Arizona  Maricopa  Phoenix  3.000000                9.0                21
# 2  Arizona  Maricopa  Phoenix  2.975000                6.6                23
# 3  Arizona  Maricopa  Phoenix  2.975000                6.6                23
# 4  Arizona  Maricopa  Phoenix  1.958333                3.0                22
#
#    SO2 AQI Date Local  year
# 0     13.0 2000-01-01  2000
# 1     13.0 2000-01-01  2000
# 2      NaN 2000-01-01  2000
# 3      NaN 2000-01-01  2000
# 4      4.0 2000-01-02  2000

# %%
#Mean SO2 levels for each state
ax = sns.barplot(x="SO2 Mean",y="State", data=SO2_data, ci=100)
fig = plt.gcf()
fig.set_size_inches(18, 13)

plt.title("Mean SO2 levels for each state")

plt.savefig("ImagesQ1/SO2_Levels_For_Each_State.png", bbox_inches="tight")

plt.show()

# %%
#CO data
CO_data = df[["State", "County", "City","CO Mean","CO 1st Max Value", "CO 1st Max Hour", "CO AQI", "Date Local","year"
                  ]]
CO_data.head()
# Out:
#      State    County     City   CO Mean  CO 1st Max Value  CO 1st Max Hour  \
# 0  Arizona  Maricopa  Phoenix  1.145833               4.2               21
# 1  Arizona  Maricopa  Phoenix  0.878947               2.2               23
# 2  Arizona  Maricopa  Phoenix  1.145833               4.2               21
# 3  Arizona  Maricopa  Phoenix  0.878947               2.2               23
# 4  Arizona  Maricopa  Phoenix  0.850000               1.6               23
#
#    CO AQI Date Local  year
# 0     NaN 2000-01-01  2000
# 1    25.0 2000-01-01  2000
# 2     NaN 2000-01-01  2000
# 3    25.0 2000-01-01  2000
# 4     NaN 2000-01-02  2000

# %%
#Mean CO levels for each state
ax = sns.barplot(x="CO Mean",y="State", data=CO_data, ci=100)
fig = plt.gcf()
fig.set_size_inches(18, 13)

plt.title("Mean CO levels for each state")

plt.savefig("ImagesQ1/CO_Levels_For_Each_State.png", bbox_inches="tight")

plt.show()

# %%
dff_group = df.groupby(["State"]).mean()

dff_group.head()
# Out:
#              NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour    NO2 AQI  \
# State
# Alabama      9.410693          22.969098         13.158029  21.232246
# Alaska      11.313152          21.046910         12.218845  19.553191
# Arizona     19.067975          38.398603         14.230985  36.106987
# Arkansas     9.753701          23.094102         12.160195  21.486471
# California  13.651894          25.592142         11.264417  24.110238
#
#              O3 Mean  O3 1st Max Value  O3 1st Max Hour     O3 AQI  SO2 Mean  \
# State
# Alabama     0.024612          0.038434         9.293026  36.845170  1.034236
# Alaska      0.012799          0.019116        10.341439  17.725431  6.083755
# Arizona     0.024989          0.043125        10.122022  39.004095  1.364213
# Arkansas    0.026169          0.038766        10.046983  35.035662  1.383302
# California  0.026053          0.038820        10.204474  35.722673  1.146695
#
#             SO2 1st Max Value  SO2 1st Max Hour    SO2 AQI   CO Mean  \
# State
# Alabama              4.230198         10.756238   7.005115  0.212607
# Alaska               9.659372          9.983789  14.487335  0.423438
# Arizona              2.728664         10.247938   4.213486  0.490616
# Arkansas             2.272116         10.036115   2.975773  0.422393
# California           2.331772          8.508692   3.598278  0.447485
#
#             CO 1st Max Value  CO 1st Max Hour    CO AQI         year     month
# State
# Alabama             0.407386         9.446257  3.850288  2014.725528  6.664107
# Alaska              0.677599        10.138804  6.528340  2014.637285  7.873354
# Arizona             0.982476         9.511755  9.191023  2007.698024  6.544301
# Arkansas            0.558514         7.939375  5.929914  2011.673610  6.482056
# California          0.769284         7.430949  7.405669  2007.483221  6.476535

# %%
df.head()
# Out:
#      State    County     City Date Local   NO2 Mean  NO2 1st Max Value  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 1  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 2  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 3  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 4  Arizona  Maricopa  Phoenix 2000-01-02  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI   O3 Mean  O3 1st Max Value  ...  SO2 Mean  \
# 0                19       46  0.022500             0.040  ...  3.000000
# 1                19       46  0.022500             0.040  ...  3.000000
# 2                19       46  0.022500             0.040  ...  2.975000
# 3                19       46  0.022500             0.040  ...  2.975000
# 4                19       34  0.013375             0.032  ...  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   CO Mean  CO 1st Max Value  \
# 0                9.0                21     13.0  1.145833               4.2
# 1                9.0                21     13.0  0.878947               2.2
# 2                6.6                23      NaN  1.145833               4.2
# 3                6.6                23      NaN  0.878947               2.2
# 4                3.0                22      4.0  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  year  month
# 0               21     NaN  2000      1
# 1               23    25.0  2000      1
# 2               21     NaN  2000      1
# 3               23    25.0  2000      1
# 4               23     NaN  2000      1
#
# [5 rows x 22 columns]

# %%
#drop unwanted columns
data = df.drop(['County','City',
                'NO2 1st Max Value','NO2 1st Max Hour',
                'O3 1st Max Value',
                'SO2 1st Max Value','SO2 1st Max Hour',
                'CO 1st Max Value','CO 1st Max Hour','year'], axis=1)
data.head()
# Out:
#      State Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 1st Max Hour  O3 AQI  \
# 0  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 1  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 2  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 3  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 4  Arizona 2000-01-02  22.958333       34  0.013375               10      27
#
#    SO2 Mean  SO2 AQI   CO Mean  CO AQI  month
# 0  3.000000     13.0  1.145833     NaN      1
# 1  3.000000     13.0  0.878947    25.0      1
# 2  2.975000      NaN  1.145833     NaN      1
# 3  2.975000      NaN  0.878947    25.0      1
# 4  1.958333      4.0  0.850000     NaN      1

# %%
#To create a seaborn plot using NO2 Mean and SO2 Mean Data
sns.FacetGrid(data, hue="State", height=5) \
   .map(plt.scatter, "SO2 AQI", "NO2 AQI") \
   .add_legend()

plt.title("SO2_Vs_NO2_byState Corelation")

plt.savefig("ImagesQ2/SO2_Vs_NO2_byState.png", bbox_inches="tight")

plt.show()

# %%
#To create a seaborn plot using O3 Mean and CO Mean Data
sns.FacetGrid(data, hue="State", height=5) \
   .map(plt.scatter, "O3 AQI", "CO AQI") \
   .add_legend()

plt.title("O3_Vs_CO_byState Corelation")

plt.savefig("ImagesQ2/O3_Vs_CO_byState.png", bbox_inches="tight")

plt.show()

# %%
Air_Onlydf = df[['NO2 AQI','O3 AQI','SO2 AQI','CO AQI']]

Air_Onlydf.head()
# Out:
#    NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# 0       46      34     13.0     NaN
# 1       46      34     13.0    25.0
# 2       46      34      NaN     NaN
# 3       46      34      NaN    25.0
# 4       34      27      4.0     NaN

# %%
sns.heatmap(Air_Onlydf.corr(), annot= True ,  fmt = ".2f"  , cmap = "YlGnBu", cbar_kws= {'label' : 'Correlation Coefficient'})
plt.title("Correlation Plot")
plt.savefig("ImagesQ2/Correlation Plot.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Interpretation:
# CO AQI and NO2 AQI stand out with the highest positiive correlation out of the bunch.

# %%
#To create a seaborn plot using NO2 Mean and CO Mean Data
sns.FacetGrid(data, hue="State", height=5) \
   .map(plt.scatter, "NO2 AQI", "CO AQI") \
   .add_legend()

plt.title("NO2_Vs_CO_byState Corelation")

plt.savefig("ImagesQ2/NO2_Vs_CO_byState.png", bbox_inches="tight")

plt.show()

# %%
df.City.unique()
# Out:
# array(['Phoenix', 'Scottsdale', 'Tucson', 'Concord', 'Bethel Island',
#        'San Pablo', 'Pittsburg', 'Calexico', 'Bakersfield', 'Burbank',
#        'Los Angeles', 'Long Beach', 'Hawthorne', 'Costa Mesa', 'Rubidoux',
#        'Not in a city', 'Arden-Arcade', 'Victorville', 'Chula Vista',
#        'San Diego', 'San Francisco', 'Capitan', 'Lompoc', 'Goleta',
#        'Vandenberg Air Force Base', 'Davenport', 'Vallejo', 'Welby',
#        'Washington', 'Winter Park', 'Chicago', 'Cicero',
#        'Calumet City (PU RR name Calumet Park (sta.))',
#        'Indianapolis (Remainder)', 'Kansas City', 'Ashland',
#        'Lexington-Fayette (corporate name for Lexington)', 'Henderson',
#        'Louisville', 'Paducah', 'Baton Rouge', 'Detroit', 'Sunset Hills',
#        'Ladue', 'Ferguson', 'St. Ann', 'St. Louis', 'Camden', 'New York',
#        'Holtsville', 'Winston-Salem', 'Charlotte', 'Park Hill',
#        'Ponca City', 'Pittsburgh', 'Beaver Falls', 'Reading', 'Altoona',
#        'Bristol', 'Johnstown', 'Scranton', 'Lancaster', 'New Castle',
#        'Norristown', 'Freemansburg', 'Philadelphia', 'Charleroi',
#        'Greensburg', 'York', 'Dallas', 'El Paso', 'Houston',
#        'Seven Corners', 'McLean', 'Alexandria', 'Oakland', 'Crockett',
#        'West Los Angeles', 'East Saint Louis', 'Boston',
#        'Breckenridge Hills', 'Boulder City', 'Newark', 'Miami',
#        'Grand Rapids', 'Manchester', 'Fresno', 'Denver', 'Kenner', 'Erie',
#        'Eureka', 'New Haven', 'Presque Isle', 'Essex', 'Tulsa',
#        'Wilkes-Barre', 'Annandale', 'Milwaukee', 'North Little Rock',
#        'Berkeley', 'Benicia', 'Westport', 'East Hartford', 'Valrico',
#        'Northbrook', 'Des Moines', 'Beltsville', 'Portland', 'Waco',
#        'Fontana', 'Cherry Tree', 'San Antonio', 'San Jose', 'Athens',
#        'Cupertino', 'Cornwall', 'Reno', 'Deer Park', 'East Highland Park',
#        'Hampton', 'El Cajon', 'Wilmington', 'Blaine', 'Albuquerque',
#        'Rochester', 'Cleveland', 'Cincinnati', 'Oklahoma City',
#        'East Providence', 'Sioux Falls', 'Salt Lake City', 'Austin',
#        'Roosevelt', 'Birmingham', 'Vinton', 'Seattle', 'Fairbanks',
#        'Grantsville', 'Raleigh', 'Riverton', 'Dentsville (Dents)'],
#       dtype=object)

# %%
# Only California Dataset
PNcal = data[df.State=="California"]
PNcal

# Adding Columns
PNcal["Date of Year"] = data['Date Local'].dt.dayofyear # Day of Year
PNcal["Weekday"] = data['Date Local'].dt.weekday

# %%
PNcal.head()
# Out:
#            State Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 1st Max Hour  \
# 3516  California 2000-01-01  14.782609       25  0.015542               13
# 3517  California 2000-01-01  14.782609       25  0.015542               13
# 3518  California 2000-01-01  14.782609       25  0.015542               13
# 3519  California 2000-01-01  14.782609       25  0.015542               13
# 3520  California 2000-01-02  16.043478       28  0.015292                9
#
#       O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  month  Date of Year  \
# 3516      25  0.636364      3.0  0.556522     NaN      1             1
# 3517      25  0.636364      3.0  0.572222     9.0      1             1
# 3518      25  0.600000      NaN  0.556522     NaN      1             1
# 3519      25  0.600000      NaN  0.572222     9.0      1             1
# 3520      27  1.000000      3.0  0.578261     NaN      1             2
#
#       Weekday
# 3516        5
# 3517        5
# 3518        5
# 3519        5
# 3520        6

# %%
# Examine Strongest Correlation in California
sns.jointplot(x=PNcal["NO2 AQI"], y=PNcal["CO AQI"],  xlim=(0,50),ylim=(0,12) , kind='kde',color='g')

plt.title("NO2 Vs CO Vizualization California")
plt.savefig("ImagesQ2/NO2_Vs_CO_VizCal.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Observation:
# As NO2 increases CO also increases

# %%
# Only Pennsylvania Dataset
PNN = data[df.State=="Pennsylvania"]
PNN

# Adding data columns by extracting from the exsisting columns

PNN["Date of Year"] = data['Date Local'].dt.dayofyear # Day of Year
PNN["Weekday"] = data['Date Local'].dt.weekday

# %%
PNN.head()
# Out:
#               State Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 1st Max Hour  \
# 69620  Pennsylvania 2000-03-31  32.875000       48  0.000000               22
# 69621  Pennsylvania 2000-03-31  32.875000       48  0.000000               22
# 69622  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
# 69623  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
# 69624  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
#
#        O3 AQI   SO2 Mean  SO2 AQI   CO Mean  CO AQI  month  Date of Year  \
# 69620       0  12.041667     47.0  0.000000     0.0      3            91
# 69621       0  12.012500      NaN  0.000000     0.0      3            91
# 69622      42   8.875000     29.0  0.220833     NaN      4            97
# 69623      42   8.875000     29.0  0.220833     3.0      4            97
# 69624      42   8.837500      NaN  0.220833     NaN      4            97
#
#        Weekday
# 69620        4
# 69621        4
# 69622        3
# 69623        3
# 69624        3

# %%
# Examine Strongest Correlation in Pennsylvania
sns.jointplot(x=PNN["NO2 AQI"], y=PNN["CO AQI"],  xlim=(0,50),ylim=(0,12) , kind='kde',color='b')

plt.title("NO2 Vs CO Vizualization Pennsylvania")
plt.savefig("ImagesQ2/NO2_Vs_CO_VizPen.png", bbox_inches="tight")
plt.show()

# %%
p_data= ['NO2 AQI','O3 AQI','SO2 AQI',"CO AQI"]
custom_df = df[['State','year','NO2 AQI','O3 AQI','SO2 AQI',"CO AQI"]]

custom_df.head()
# Out:
#      State  year  NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# 0  Arizona  2000       46      34     13.0     NaN
# 1  Arizona  2000       46      34     13.0    25.0
# 2  Arizona  2000       46      34      NaN     NaN
# 3  Arizona  2000       46      34      NaN    25.0
# 4  Arizona  2000       34      27      4.0     NaN

# %%
for col in p_data:
    custom_df[col] =(custom_df[col] - custom_df[col].mean())/custom_df[col].std(ddof=0)
    
#.stack()
custom_df = custom_df.melt(["State", "year"])
custom_df.head()
# Out:
#      State  year variable     value
# 0  Arizona  2000  NO2 AQI  1.468846
# 1  Arizona  2000  NO2 AQI  1.468846
# 2  Arizona  2000  NO2 AQI  1.468846
# 3  Arizona  2000  NO2 AQI  1.468846
# 4  Arizona  2000  NO2 AQI  0.674120

# %%
# Create Heatmap Pivot with State as Row, Year as Col, So2 as Value
p_data= ['NO2 AQI','O3 AQI','SO2 AQI',"CO AQI"]


f, ax = plt.subplots(figsize=(16,40))
ax.set_title('All AQI by State and Year')
sns.heatmap(custom_df.pivot_table(values="value", 
                                  index=["State", "variable"], 
                                  columns=["year"], 
                                  aggfunc='mean',margins=True),
                                  annot=False, 
                                  linewidths=.5, 
                                  ax=ax,cbar_kws={'label': 'Annual Average'}, cmap="YlGnBu")

plt.title("All AQI by State and Year")
plt.savefig("ImagesQ3/All AQI by State and Year.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# What we can see fro here, pollution is getting better on a average scale.
# But, many states in the US still needs improvement, still they suffer from these polluted air because of many reasons.

# %%
len(df.State.unique())
# Out:
# 46

# %%
## Prepare all 4 AQIs against state and date 

df_State = df[['State','Date Local','NO2 AQI','O3 AQI','SO2 AQI','CO AQI']]

df_State.head()
# Out:
#      State Date Local  NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# 0  Arizona 2000-01-01       46      34     13.0     NaN
# 1  Arizona 2000-01-01       46      34     13.0    25.0
# 2  Arizona 2000-01-01       46      34      NaN     NaN
# 3  Arizona 2000-01-01       46      34      NaN    25.0
# 4  Arizona 2000-01-02       34      27      4.0     NaN

# %%
pollSt = df_State.groupby(['State','Date Local']).mean()  # Take mean values if there are depulicated entries
pollSt.head()
# Out:
#                     NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# State   Date Local
# Alabama 2013-12-01     37.0    24.0      1.0     6.0
#         2013-12-02     30.0    12.0      3.0     6.0
#         2013-12-03     21.0    11.0      3.0     3.0
#         2013-12-04     18.0    13.0      1.0     2.0
#         2013-12-05     15.0    13.0      1.0     2.0

# %%
pollStGrouped = pollSt.groupby(level=0)
pollStGrouped

# %%
plt.figure(figsize=(20,13))

# NO2 AQI
plt.subplot(221)
pollNO2 = pollStGrouped['NO2 AQI']
pollNO2Top = pollNO2.mean().nlargest(5).index
for i in range(len(pollNO2Top)):
    pollNO2.get_group(pollNO2Top[i]).groupby(pd.Grouper(level='Date Local',freq='M')).mean().plot()
plt.legend(pollNO2Top,loc=3,fontsize='small')
plt.title('NO2 AQI')

plt.savefig("ImagesQ4/NO2_Top5WithYears.png", bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,13))

# O3 AQI
plt.subplot(222)
pollO3 = pollStGrouped['O3 AQI']
pollO3Top = pollO3.mean().nlargest(5).index
for i in range(len(pollO3Top)):
    pollO3.get_group(pollO3Top[i]).groupby(pd.Grouper(level='Date Local',freq='M')).mean().plot()
plt.legend(pollO3Top,loc=3,fontsize='small')
plt.title('O3 AQI')


plt.savefig("ImagesQ4/O3_Top5WithYears.png", bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,13))

# SO2 AQI
plt.subplot(223)
pollSO2 = pollStGrouped['SO2 AQI']
pollSO2Top = pollSO2.mean().nlargest(5).index
for i in range(len(pollSO2Top)):
    pollSO2.get_group(pollSO2Top[i]).groupby(pd.Grouper(level='Date Local',freq='M')).mean().plot()
plt.legend(pollSO2Top,loc=3,fontsize='small')
plt.title('SO2 AQI')

plt.savefig("ImagesQ4/SO2_Top5WithYears.png", bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,13))

# CO AQI
plt.subplot(224)
pollCO = pollStGrouped['CO AQI']
pollCOTop = pollCO.mean().nlargest(5).index
for i in range(len(pollCOTop)):
    pollCO.get_group(pollCOTop[i]).groupby(pd.Grouper(level='Date Local',freq='M')).mean().plot()
plt.legend(pollCOTop,loc=3,fontsize='small')
plt.title('CO AQI')

plt.savefig("ImagesQ4/CO_Top5WithYears.png", bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
#To view the number of monitoring sites by state:
df["State"].value_counts()
# Out:
# California              576142
# Pennsylvania            188892
# Texas                   123208
# New York                 70487
# Arizona                  69840
# Illinois                 50116
# North Carolina           37126
# Virginia                 36422
# Arkansas                 35332
# Colorado                 35188
# Oklahoma                 34420
# Kansas                   31480
# Connecticut              29933
# New Jersey               26732
# Florida                  25918
# Iowa                     25850
# District Of Columbia     25696
# Louisiana                23874
# Maine                    23623
# Maryland                 23538
# Ohio                     22934
# Massachusetts            21572
# Hawaii                   20276
# Missouri                 19778
# Kentucky                 14686
# Indiana                  13926
# Wyoming                  13048
# Oregon                   11794
# North Dakota             11018
# Nevada                    9698
# New Hampshire             9294
# Utah                      8668
# South Dakota              8316
# Michigan                  8182
# Georgia                   7722
# New Mexico                7130
# South Carolina            6536
# Rhode Island              6324
# Tennessee                 5842
# Delaware                  3630
# Minnesota                 3558
# Alabama                   3126
# Alaska                    1974
# Idaho                     1828
# Wisconsin                 1516
# Washington                 962
# Name: State, dtype: int64

# %%
# Plot the aggregate decrease of all pollutants
f, ax = plt.subplots(figsize=[18,8])
df.groupby(['year']).agg({'SO2 AQI': 'mean',
                          'CO AQI': 'mean',
                          'NO2 AQI': 'mean',
                          'O3 AQI': 'mean'})\
.plot(colormap='jet',marker='.',markersize=10, ax =ax,linewidth=2.5)
ax.set_title('Mean Pollutant AQI Over Time')

plt.savefig("ImagesQ5/Average AQI Over Time.png" , bbox_inches="tight")


ax.set(xlabel="Average AQI", ylabel="Year")
plt.show()

# %%
#By State - mean of the NO2 1st Max Value

states_no2_1st_val = df.groupby(["State"], as_index=False)["NO2 1st Max Value"].mean()
states_no2_1st_val = states_no2_1st_val.sort_values("NO2 1st Max Value", ascending=False)


plt.figure(figsize=(20,8))
plt.bar( states_no2_1st_val['State'], states_no2_1st_val['NO2 1st Max Value'], color='green')

plt.xlabel("State Name")
plt.ylabel("Avg. NO2 1st Max Value")
plt.title("By State - mean of the NO2 1st Max Value")

plt.xticks(rotation=45)


plt.savefig("ImagesQ6/By State - mean of the NO2 1st Max Value.png" , bbox_inches="tight")

plt.tight_layout()
plt.show()

# %%
#SO2

states_so2_1st_val = df.groupby(["State"], as_index=False)["SO2 1st Max Value"].mean()
states_so2_1st_val = states_so2_1st_val.sort_values("SO2 1st Max Value", ascending=False)


plt.figure(figsize=(20,8))
plt.bar( states_so2_1st_val['State'], states_so2_1st_val['SO2 1st Max Value'], color='blue')

plt.xlabel("State Name")
plt.ylabel("Avg. SO2 1st Max Value")
plt.title("By State - mean of the SO2 1st Max Value")

plt.xticks(rotation=45)
#plt.set_cmap(states_no2_1st_val["State"], rotation=45)


plt.savefig("ImagesQ6/By State - mean of the SO2 1st Max Value.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
#CO

states_co_1st_val = df.groupby(["State"], as_index=False)["CO 1st Max Value"].mean()
states_co_1st_val = states_co_1st_val.sort_values("CO 1st Max Value", ascending=False)

plt.figure(figsize=(20,8))
plt.bar( states_co_1st_val['State'], states_co_1st_val['CO 1st Max Value'], color='pink')

plt.xlabel("State Name")
plt.ylabel("Avg. CO 1st Max Value")
plt.title("By State - mean of the CO 1st Max Value")

plt.xticks(rotation=45)
#plt.set_cmap(states_no2_1st_val["State"], rotation=45)

plt.savefig("ImagesQ6/By State - mean of the CO 1st Max Value.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
#O3

states_o3_1st_val = df.groupby(["State"], as_index=False)["O3 1st Max Value"].mean()
states_o3_1st_val = states_o3_1st_val.sort_values("O3 1st Max Value", ascending=False)

plt.figure(figsize=(20,8))
plt.bar( states_o3_1st_val['State'], states_o3_1st_val['O3 1st Max Value'], color='orange')

plt.xlabel("State Name")
plt.ylabel("Avg. O3 1st Max Value")
plt.title("By State - mean of the O3 1st Max Value")

plt.xticks(rotation=45)
#plt.set_cmap(states_no2_1st_val["State"], rotation=45)

plt.savefig("ImagesQ6/By State - mean of the O3 1st Max Value.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
x =df['State']
x.unique()
# Out:
# array(['Arizona', 'California', 'Colorado', 'District Of Columbia',
#        'Florida', 'Illinois', 'Indiana', 'Kansas', 'Kentucky',
#        'Louisiana', 'Michigan', 'Missouri', 'New Jersey', 'New York',
#        'North Carolina', 'Oklahoma', 'Pennsylvania', 'Texas', 'Virginia',
#        'Massachusetts', 'Nevada', 'New Hampshire', 'Tennessee',
#        'South Carolina', 'Connecticut', 'Iowa', 'Maine', 'Maryland',
#        'Wisconsin', 'Arkansas', 'Oregon', 'Wyoming', 'North Dakota',
#        'Idaho', 'Ohio', 'Georgia', 'Delaware', 'Hawaii', 'Minnesota',
#        'New Mexico', 'Rhode Island', 'South Dakota', 'Utah', 'Alabama',
#        'Washington', 'Alaska'], dtype=object)

# %%
df.dtypes
# Out:
# State                        object
# County                       object
# City                         object
# Date Local           datetime64[ns]
# NO2 Mean                    float64
# NO2 1st Max Value           float64
# NO2 1st Max Hour              int64
# NO2 AQI                       int64
# O3 Mean                     float64
# O3 1st Max Value            float64
# O3 1st Max Hour               int64
# O3 AQI                        int64
# SO2 Mean                    float64
# SO2 1st Max Value           float64
# SO2 1st Max Hour              int64
# SO2 AQI                     float64
# CO Mean                     float64
# CO 1st Max Value            float64
# CO 1st Max Hour               int64
# CO AQI                      float64
# year                          int64
# month                         int64
# dtype: object

# %%
state_2016_df.head()
# Out:
#          State  Population    Area
# 0     .Alabama     4864745   50750
# 1     .Arizona     6945452  113642
# 2    .Arkansas     2990410   52075
# 3  .California    39209127  155973
# 4    .Colorado     5540921  103730

# %%
df.head()
# Out:
#      State    County     City Date Local   NO2 Mean  NO2 1st Max Value  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 1  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 2  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 3  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 4  Arizona  Maricopa  Phoenix 2000-01-02  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI   O3 Mean  O3 1st Max Value  ...  SO2 Mean  \
# 0                19       46  0.022500             0.040  ...  3.000000
# 1                19       46  0.022500             0.040  ...  3.000000
# 2                19       46  0.022500             0.040  ...  2.975000
# 3                19       46  0.022500             0.040  ...  2.975000
# 4                19       34  0.013375             0.032  ...  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   CO Mean  CO 1st Max Value  \
# 0                9.0                21     13.0  1.145833               4.2
# 1                9.0                21     13.0  0.878947               2.2
# 2                6.6                23      NaN  1.145833               4.2
# 3                6.6                23      NaN  0.878947               2.2
# 4                3.0                22      4.0  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  year  month
# 0               21     NaN  2000      1
# 1               23    25.0  2000      1
# 2               21     NaN  2000      1
# 3               23    25.0  2000      1
# 4               23     NaN  2000      1
#
# [5 rows x 22 columns]

# %%
df_16 = df[df.year == 2016]
df_16.head()
# Out:
#            State     County        City Date Local  NO2 Mean  \
# 1722057  Alabama  Jefferson  Birmingham 2016-01-01  2.520833
# 1722058  Alabama  Jefferson  Birmingham 2016-01-01  2.520833
# 1722059  Alabama  Jefferson  Birmingham 2016-01-01  2.520833
# 1722060  Alabama  Jefferson  Birmingham 2016-01-01  2.520833
# 1722061  Alabama  Jefferson  Birmingham 2016-01-02  8.437500
#
#          NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI   O3 Mean  \
# 1722057                4.1                11        4  0.022292
# 1722058                4.1                11        4  0.022292
# 1722059                4.1                11        4  0.022292
# 1722060                4.1                11        4  0.022292
# 1722061               27.5                18       25  0.015333
#
#          O3 1st Max Value  ...  SO2 Mean  SO2 1st Max Value  SO2 1st Max Hour  \
# 1722057             0.027  ...  0.413636                1.2                 3
# 1722058             0.027  ...  0.413636                1.2                 3
# 1722059             0.027  ...  0.400000                0.7                 5
# 1722060             0.027  ...  0.400000                0.7                 5
# 1722061             0.030  ...  0.663636                1.4                 3
#
#          SO2 AQI   CO Mean  CO 1st Max Value  CO 1st Max Hour  CO AQI  year  \
# 1722057      1.0  0.129545              0.14                2     NaN  2016
# 1722058      1.0  0.100000              0.10                7     1.0  2016
# 1722059      NaN  0.129545              0.14                2     NaN  2016
# 1722060      NaN  0.100000              0.10                7     1.0  2016
# 1722061      1.0  0.259091              0.71               23     NaN  2016
#
#          month
# 1722057      1
# 1722058      1
# 1722059      1
# 1722060      1
# 1722061      1
#
# [5 rows x 22 columns]

# %%
state_df = df_16.groupby(["State"])
state_16 = state_df[["State","NO2 AQI","O3 AQI", 'SO2 AQI', "CO AQI"
                          ]]

final_16 = state_16.mean()
final_16
# Out:
#                         NO2 AQI     O3 AQI   SO2 AQI    CO AQI
# State
# Alabama               23.093960  39.295302  5.275168  3.906040
# Arizona               29.652941  37.370588  1.117647  7.788235
# Arkansas              20.274725  32.824176  0.824176  4.637363
# California            16.164364  32.900000  1.172965  5.664727
# Colorado              42.159851  31.286245  3.947955  7.843866
# Delaware              25.988095  32.047619  1.952381  4.464286
# District Of Columbia  25.689655  38.913793  2.206897  3.586207
# Florida               13.857143  36.868132  0.813187  7.406593
# Georgia               25.333333  29.634921  0.555556  5.253968
# Illinois              20.837989  31.201117  3.145251  4.435754
# Indiana               23.969072  35.154639  1.381443  3.907216
# Iowa                  12.884615  37.263736  0.296703  2.675824
# Kansas                24.165714  29.542857  2.750000  4.040000
# Louisiana             24.991228  34.368421  2.964912  3.298246
# Maine                 18.048951  33.118881  1.587413  4.139860
# Maryland              17.641791  33.522388  1.988806  3.738806
# Massachusetts         26.604396  28.164835  1.021978  4.010989
# Missouri              25.040816  27.816327  2.693878  4.755102
# Nevada                30.153846  32.782051  1.512821  5.256410
# New Hampshire          8.305085  34.118644  1.237288  2.525424
# New York              30.907950  29.606695  2.686192  4.334728
# North Carolina        17.046809  37.702128  0.523404  3.804255
# North Dakota          11.000000  29.417582  0.087912  2.153846
# Ohio                  20.500000  31.280556  9.602778  4.138889
# Oklahoma              18.931507  35.780822  2.534247  5.068493
# Pennsylvania          15.604511  33.413534  4.209581  1.723308
# Rhode Island          15.925620  36.851240  0.636364  3.206612
# South Carolina        18.655172  36.758621  0.517241  2.482759
# Tennessee              1.708075  39.167702  0.161491  2.037500
# Texas                 21.184762  35.634286  1.377143  4.030476
# Utah                  43.142857  21.952381  1.000000  8.333333
# Virginia              20.550000  29.350000  1.166667  4.450000
# Washington            26.586207  23.689655  0.733333  4.206897
# Wyoming               10.288889  41.077778  0.200000  1.155556

# %%
x = state_2016_df['Population']
y = state_2016_df['Area']
s = final_16['NO2 AQI']
y = y.astype(np.float)
x = x.astype(np.float)

xs = state_2016_df['Population']
ys = state_2016_df['Area']
ss = final_16['O3 AQI']
ys = y.astype(np.float)
xs = x.astype(np.float)

# %%
plt.scatter(x.values, 
            y.values, 
            s*10, c="green", 
            edgecolor="black", linewidths=1, marker="o")


plt.title("Population vs Area Correlation for O3 (2016)")
plt.ylabel("Land Area (square miles)")
plt.xlabel("Population")
plt.grid(True)

plt.savefig("ImagesQ7/O3_pop_vs_area.png")

#plt.text(10,30, "Note:\nState Population and Land Area does not direclty correlate with Air Quality")

# %%
plt.scatter(xs.values, 
            ys.values, 
            ss*10, c="yellow", 
            edgecolor="black", linewidths=1, marker="o")


plt.title("Population vs Area Correlation for SO2 (2016)")
plt.ylabel("Land Area (square miles)")
plt.xlabel("Population")
plt.grid(True)

plt.savefig("ImagesQ7/SO2_pop_vs_area.png")

# %%
#CO data
CO_data = df[["State", "County", "City","CO Mean","CO 1st Max Value", "CO 1st Max Hour", "CO AQI", "Date Local","year"
                  ]]
state_CO_data = CO_data.groupby(['State']).mean()
state_CO_data
# Out:
#                        CO Mean  CO 1st Max Value  CO 1st Max Hour     CO AQI  \
# State
# Alabama               0.212607          0.407386         9.446257   3.850288
# Alaska                0.423438          0.677599        10.138804   6.528340
# Arizona               0.490616          0.982476         9.511755   9.191023
# Arkansas              0.422393          0.558514         7.939375   5.929914
# California            0.447485          0.769284         7.430949   7.405669
# Colorado              0.443112          0.814280         8.691912   7.724205
# Connecticut           0.250866          0.366647         8.229045   3.586407
# Delaware              0.261600          0.401025         8.929477   3.839384
# District Of Columbia  0.790170          1.125385         9.308608  11.605105
# Florida               0.425255          0.574432         6.743885   5.921593
# Georgia               0.321501          0.524029         9.099974   5.273057
# Hawaii                0.367477          0.426746         4.415368   4.483133
# Idaho                 0.178148          0.323575         8.680525   2.876368
# Illinois              0.392759          0.623553         8.528953   6.258436
# Indiana               0.357091          0.536191         7.772153   5.395489
# Iowa                  0.217115          0.323235         8.823404   3.043098
# Kansas                0.408664          0.650119         8.714041   6.541775
# Kentucky              0.164495          0.372856         7.525943   3.178207
# Louisiana             0.412347          0.643143         8.280305   6.311804
# Maine                 0.225925          0.312399         8.160606   3.087476
# Maryland              0.281359          0.452259         8.149970   4.370254
# Massachusetts         0.318438          0.526043        10.228166   5.539959
# Michigan              0.348478          0.705353         8.548521   6.469956
# Minnesota             0.244840          0.347234         8.908375   3.447804
# Missouri              0.467052          0.746112         9.170341   7.413727
# Nevada                0.221208          0.410696         7.697876   3.658688
# New Hampshire         0.344256          0.494148         7.823542   5.073181
# New Jersey            0.402450          0.647450         8.613796   6.437336
# New Mexico            0.210986          0.401212         8.705610   3.482323
# New York              0.356876          0.569969         8.468484   5.657804
# North Carolina        0.354826          0.563985         9.081506   5.628313
# North Dakota          0.168464          0.221697         8.106371   2.053358
# Ohio                  0.270534          0.423377         8.679820   4.009942
# Oklahoma              0.140372          0.279178         7.261505   2.488292
# Oregon                0.305456          0.547753         9.466000   5.323724
# Pennsylvania          0.241592          0.416914         7.226145   3.986757
# Rhode Island          0.224068          0.335547         7.844719   3.162025
# South Carolina        0.124604          0.175459         3.962362   1.604651
# South Dakota          0.181980          0.258525         6.806157   2.385948
# Tennessee             0.438306          0.458800         4.014379   4.878684
# Texas                 0.247957          0.488641         8.080052   4.450380
# Utah                  0.354011          0.589878         7.018920   5.413475
# Virginia              0.373085          0.522135         7.434188   5.359833
# Washington            0.204777          0.288636         8.744283   2.719335
# Wisconsin             0.350427          0.559103         6.266491   5.248021
# Wyoming               0.108020          0.152553         6.379675   1.486047
#
#                              year
# State
# Alabama               2014.725528
# Alaska                2014.637285
# Arizona               2007.698024
# Arkansas              2011.673610
# California            2007.483221
# Colorado              2009.411504
# Connecticut           2011.298400
# Delaware              2012.819284
# District Of Columbia  2008.048490
# Florida               2007.610387
# Georgia               2012.933437
# Hawaii                2012.924245
# Idaho                 2009.888403
# Illinois              2007.523266
# Indiana               2009.044808
# Iowa                  2012.312650
# Kansas                2006.123189
# Kentucky              2002.503473
# Louisiana             2007.579375
# Maine                 2011.068027
# Maryland              2011.765910
# Massachusetts         2008.068515
# Michigan              2003.426546
# Minnesota             2013.277684
# Missouri              2004.677824
# Nevada                2010.317797
# New Hampshire         2008.196471
# New Jersey            2008.131902
# New Mexico            2012.998597
# New York              2007.316526
# North Carolina        2008.853203
# North Dakota          2011.523325
# Ohio                  2012.912357
# Oklahoma              2008.302963
# Oregon                2011.163982
# Pennsylvania          2006.857029
# Rhode Island          2013.583175
# South Carolina        2007.654835
# South Dakota          2012.950216
# Tennessee             2008.297501
# Texas                 2008.827446
# Utah                  2012.741578
# Virginia              2008.710779
# Washington            2014.665281
# Wisconsin             2006.081794
# Wyoming               2011.909718

# %%
state_co_group = state_CO_data.loc[:,["CO AQI"]]

state_CO_high = state_co_group.sort_values('CO AQI', ascending=False)
state_CO_low = state_co_group.sort_values('CO AQI', ascending=True)


co_high = state_CO_high.head(5)
co_low = state_CO_low.head(5)

# %%
co_high.plot(kind="bar", grid=True, figsize=(10,10),
              title="CO Top 5 States", color='red', ylim=(0, 12))
co_low.plot(kind="bar", grid=True, figsize=(10,10),
              title="CO Low 5 States", ylim=(0, 12))

plt.savefig("ImagesQ8/CO_state_5.png")


plt.show()

# %%
state_so2_data = SO2_data.groupby(['State']).mean()

state_so2_group = state_so2_data.loc[:,["SO2 AQI"]]

top_state_so2 = state_so2_group.sort_values("SO2 AQI", ascending=False)
low_state_so2 = state_so2_group.sort_values("SO2 AQI", ascending=True)

so2_high = top_state_so2.head(5)
so2_low = low_state_so2.head(5)

# %%
so2_high.plot(kind="bar", grid=True, figsize=(10,10),
              title="SO2 Top 5 States", color='red', ylim=(0, 20))
so2_low.plot(kind="bar", grid=True, figsize=(10,10),
              title="SO2 Low 5 States", ylim=(0, 20))

plt.savefig("ImagesQ8/SO2_state_5.png")

plt.show()

# %%
state_o3_data = O3_data.groupby(['State']).mean()

state_o3_group = state_o3_data.loc[:,["O3 AQI"]]

top_state_o3 = state_o3_group.sort_values("O3 AQI", ascending=False)
low_state_o3 = state_o3_group.sort_values("O3 AQI", ascending=True)

o3_high = top_state_o3.head(5)
o3_low = low_state_o3.head(5)

# %%
#plt.subplots(1,2, figsize=[15,5])

o3_high.plot(kind="bar", grid=True, figsize=(10,10),
              title="O3 Top 5 States", color='red', ylim=(0, 50))
o3_low.plot(kind="bar", grid=True, figsize=(10,10),
              title="O3 Low 5 States", ylim=(0, 50))

plt.savefig("ImagesQ8/O3_state_5.png")

plt.show()

# %%
state_no2_data = NO2_data.groupby(['State']).mean()

state_no2_group = state_no2_data.loc[:,["NO2 AQI"]]

top_state_no2 = state_no2_group.sort_values("NO2 AQI", ascending=False)
low_state_no2 = state_no2_group.sort_values("NO2 AQI", ascending=True)

no2_high = top_state_no2.head(5)
no2_low = low_state_no2.head(5)

# %%
no2_high.plot(kind="bar", grid=True, figsize=(10,10),
              title="NO2 Top 5 States", color='red', ylim=(0, 40))
no2_low.plot(kind="bar", grid=True, figsize=(10,10),
              title="NO2 Low 5 States", ylim=(0, 40))

plt.savefig("ImagesQ8/NO2_state_5.png")

plt.show()

# %%
data.head()
# Out:
#      State Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 1st Max Hour  O3 AQI  \
# 0  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 1  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 2  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 3  Arizona 2000-01-01  19.041667       46  0.022500               10      34
# 4  Arizona 2000-01-02  22.958333       34  0.013375               10      27
#
#    SO2 Mean  SO2 AQI   CO Mean  CO AQI  month
# 0  3.000000     13.0  1.145833     NaN      1
# 1  3.000000     13.0  0.878947    25.0      1
# 2  2.975000      NaN  1.145833     NaN      1
# 3  2.975000      NaN  0.878947    25.0      1
# 4  1.958333      4.0  0.850000     NaN      1

# %%
df.head()
# Out:
#      State    County     City Date Local   NO2 Mean  NO2 1st Max Value  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 1  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 2  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 3  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 4  Arizona  Maricopa  Phoenix 2000-01-02  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI   O3 Mean  O3 1st Max Value  ...  SO2 Mean  \
# 0                19       46  0.022500             0.040  ...  3.000000
# 1                19       46  0.022500             0.040  ...  3.000000
# 2                19       46  0.022500             0.040  ...  2.975000
# 3                19       46  0.022500             0.040  ...  2.975000
# 4                19       34  0.013375             0.032  ...  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   CO Mean  CO 1st Max Value  \
# 0                9.0                21     13.0  1.145833               4.2
# 1                9.0                21     13.0  0.878947               2.2
# 2                6.6                23      NaN  1.145833               4.2
# 3                6.6                23      NaN  0.878947               2.2
# 4                3.0                22      4.0  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  year  month
# 0               21     NaN  2000      1
# 1               23    25.0  2000      1
# 2               21     NaN  2000      1
# 3               23    25.0  2000      1
# 4               23     NaN  2000      1
#
# [5 rows x 22 columns]

# %%
# Only California Dataset
PN = data[df.State=="Pennsylvania"]
PN.head()
# Out:
#               State Date Local   NO2 Mean  NO2 AQI   O3 Mean  O3 1st Max Hour  \
# 69620  Pennsylvania 2000-03-31  32.875000       48  0.000000               22
# 69621  Pennsylvania 2000-03-31  32.875000       48  0.000000               22
# 69622  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
# 69623  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
# 69624  Pennsylvania 2000-04-06  13.956522       35  0.032625               11
#
#        O3 AQI   SO2 Mean  SO2 AQI   CO Mean  CO AQI  month
# 69620       0  12.041667     47.0  0.000000     0.0      3
# 69621       0  12.012500      NaN  0.000000     0.0      3
# 69622      42   8.875000     29.0  0.220833     NaN      4
# 69623      42   8.875000     29.0  0.220833     3.0      4
# 69624      42   8.837500      NaN  0.220833     NaN      4

# %%
datanewNO2 =

# %%
datanewNO2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-25f34a88d47f> in <module>
# ----> 1 datanewNO2.head()
#
# NameError: name 'datanewNO2' is not defined

# %%
PNx = datanewNO2[datanewNO2.State=="California"]
PNx.head()

# %%
# Time Frames of Interest
datanewNO2["Date of Year"] = datanewNO2['Date Local'].dt.dayofyear # Day of Year
datanewNO2["Weekday"] = datanewNO2['Date Local'].dt.weekday 
datanewNO2.head()

# %%
PollnewNO2 = PNx.groupby(['State','City']).mean()  # Take mean values if there are depulicated entries
PollnewNO2.head()

# %%
pollStGroupedN = PollnewNO2.groupby(level=0)
pollStGroupedN

# %%
data.head()

# %%
datanewNO2.head()

# %%
# Cities and NO2 data
city_dataNO2 = datanewNO2[["City", "Date of Year","NO2 AQI"]]\
    .groupby(['City', 'Date of Year']).mean().groupby(level="City")

plt.figure(figsize=(20,12))
for air1,plot in [('NO2 AQI',221)]:
        plt.subplot(plot)
        city_dataNO2_plot = city_dataNO2[air1]
        city_dataNO2_plotTop = city_dataNO2_plot.mean().nlargest(5).index
        for i in city_dataNO2_plotTop:
            plot1= city_dataNO2_plot.get_group(i).groupby(pd.Grouper(level='Date of Year'))\
            .mean().plot()
        plt.title(air1)
        plt.xlabel('Date of Year')
        plt.ylabel("NO2 Air Quality Index")
        plt.legend(city_dataNO2_plotTop, loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=5)

plt.tight_layout()
#plt.subplots_adjust()
plt.suptitle("Trend of Average Pollutant NO2 by Top 5 City by Date of the Year",fontsize=17)
#plt.savefig('Trend of Average Pollutant by Top 5 City.png')
plt.show()

# %%
df.head()
# Out:
#      State    County     City Date Local   NO2 Mean  NO2 1st Max Value  \
# 0  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 1  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 2  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 3  Arizona  Maricopa  Phoenix 2000-01-01  19.041667               49.0
# 4  Arizona  Maricopa  Phoenix 2000-01-02  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI   O3 Mean  O3 1st Max Value  ...  SO2 Mean  \
# 0                19       46  0.022500             0.040  ...  3.000000
# 1                19       46  0.022500             0.040  ...  3.000000
# 2                19       46  0.022500             0.040  ...  2.975000
# 3                19       46  0.022500             0.040  ...  2.975000
# 4                19       34  0.013375             0.032  ...  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour  SO2 AQI   CO Mean  CO 1st Max Value  \
# 0                9.0                21     13.0  1.145833               4.2
# 1                9.0                21     13.0  0.878947               2.2
# 2                6.6                23      NaN  1.145833               4.2
# 3                6.6                23      NaN  0.878947               2.2
# 4                3.0                22      4.0  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  year  month
# 0               21     NaN  2000      1
# 1               23    25.0  2000      1
# 2               21     NaN  2000      1
# 3               23    25.0  2000      1
# 4               23     NaN  2000      1
#
# [5 rows x 22 columns]

# %%
customx_df = df[['State','Date Local','City','year','NO2 AQI','O3 AQI','SO2 AQI',"CO AQI"]]
customx_df.head()
# Out:
#      State Date Local     City  year  NO2 AQI  O3 AQI  SO2 AQI  CO AQI
# 0  Arizona 2000-01-01  Phoenix  2000       46      34     13.0     NaN
# 1  Arizona 2000-01-01  Phoenix  2000       46      34     13.0    25.0
# 2  Arizona 2000-01-01  Phoenix  2000       46      34      NaN     NaN
# 3  Arizona 2000-01-01  Phoenix  2000       46      34      NaN    25.0
# 4  Arizona 2000-01-02  Phoenix  2000       34      27      4.0     NaN

# %%
# Time Frames of Interest
customx_df["Date of Year"] = customx_df['Date Local'].dt.dayofyear # Day of Year
customx_df["Weekday"] = customx_df['Date Local'].dt.weekday

# %%
customx_df.head()
# Out:
#      State Date Local     City  year  NO2 AQI  O3 AQI  SO2 AQI  CO AQI  \
# 0  Arizona 2000-01-01  Phoenix  2000       46      34     13.0     NaN
# 1  Arizona 2000-01-01  Phoenix  2000       46      34     13.0    25.0
# 2  Arizona 2000-01-01  Phoenix  2000       46      34      NaN     NaN
# 3  Arizona 2000-01-01  Phoenix  2000       46      34      NaN    25.0
# 4  Arizona 2000-01-02  Phoenix  2000       34      27      4.0     NaN
#
#    Date of Year  Weekday
# 0             1        5
# 1             1        5
# 2             1        5
# 3             1        5
# 4             2        6

# %%
# Cities and SO2 data
city_dataSO2 = customx_df[["City", "Date of Year","SO2 AQI"]]\
    .groupby(['City', 'Date of Year']).mean().groupby(level="City")

plt.figure(figsize=(20,12))
for air2,plot in [('SO2 AQI',221)]:
        plt.subplot(plot)
        city_dataSO2_plot = city_dataSO2[air2]
        city_dataSO2_plotTop = city_dataSO2_plot.mean().nlargest(5).index
        for i in city_dataSO2_plotTop:
            plot1= city_dataSO2_plot.get_group(i).groupby(pd.Grouper(level='Date of Year'))\
            .mean().plot()
        plt.title(air2)
        plt.xlabel('Date of Year')
        plt.ylabel("SO2 Air Quality Index")
        plt.legend(city_dataSO2_plotTop, loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=4)

plt.tight_layout()

plt.savefig("ImagesQ10/Trend of Average Pollutant SO2 of Top 5 City by Date of the Year",fontsize=17)

plt.show()

# %%
# Cities and CO data
city_dataCO = customx_df[["City", "Date of Year","CO AQI"]]\
    .groupby(['City', 'Date of Year']).mean().groupby(level="City")

plt.figure(figsize=(20,12))
for air3,plot in [('CO AQI',221)]:
        plt.subplot(plot)
        city_dataCO_plot = city_dataCO[air3]
        city_dataCO_plotTop = city_dataCO_plot.mean().nlargest(5).index
        for i in city_dataCO_plotTop:
            plot1= city_dataCO_plot.get_group(i).groupby(pd.Grouper(level='Date of Year'))\
            .mean().plot()
        plt.title(air3)
        plt.xlabel('Date of Year')
        plt.ylabel("CO Air Quality Index")
        plt.legend(city_dataCO_plotTop, loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=5)

plt.tight_layout()

plt.savefig("ImagesQ10/Trend of Average Pollutant CO of Top 5 City by Date of the Year",fontsize=17)

plt.show()

# %%
# Cities and O3 data
city_dataO3 = customx_df[["City", "Date of Year","O3 AQI"]]\
    .groupby(['City', 'Date of Year']).mean().groupby(level="City")

plt.figure(figsize=(20,12))
for air4,plot in [('O3 AQI',221)]:
        plt.subplot(plot)
        city_dataO3_plot = city_dataO3[air4]
        city_dataO3_plotTop = city_dataO3_plot.mean().nlargest(5).index
        for i in city_dataO3_plotTop:
            plot1= city_dataO3_plot.get_group(i).groupby(pd.Grouper(level='Date of Year'))\
            .mean().plot()
        plt.title(air4)
        plt.xlabel('Date of Year')
        plt.ylabel("O3 Air Quality Index")
        plt.legend(city_dataO3_plotTop, loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=5)

plt.tight_layout()

plt.savefig("ImagesQ10/Trend of Average Pollutant O3 of Top 5 City by Date of the Year",fontsize=17)

plt.show()

# %%
# Cities and NO2 data
city_dataNO2x = customx_df[["City", "Date of Year","NO2 AQI"]]\
    .groupby(['City', 'Date of Year']).mean().groupby(level="City")

plt.figure(figsize=(20,12))
for air5,plot in [('NO2 AQI',221)]:
        plt.subplot(plot)
        city_dataNO2x_plot = city_dataNO2x[air5]
        city_dataNO2x_plotTop = city_dataNO2x_plot.mean().nlargest(5).index
        for i in city_dataNO2x_plotTop:
            plot1= city_dataNO2x_plot.get_group(i).groupby(pd.Grouper(level='Date of Year'))\
            .mean().plot()
        plt.title(air5)
        plt.xlabel('Date of Year')
        plt.ylabel("NO2 Air Quality Index")
        plt.legend(city_dataNO2x_plotTop, loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=5)

plt.tight_layout()

plt.savefig("ImagesQ10/Trend of Average Pollutant NO2 of Top 5 City by Date of the Year",fontsize=17)

plt.show()

# %%
df['month'] = pd.DatetimeIndex(df['Date Local']).month

# %%
# Separating the Louisiana data 
la = df[df.State=='District Of Columbia'][["NO2 AQI","SO2 AQI","CO AQI","Date Local","year","month"
                   ]]
la.head()
# Out:
#        NO2 AQI  SO2 AQI  CO AQI Date Local  year  month
# 39766       37     47.0     NaN 2000-01-01  2000      1
# 39767       37     47.0    41.0 2000-01-01  2000      1
# 39768       37      NaN     NaN 2000-01-01  2000      1
# 39769       37      NaN    41.0 2000-01-01  2000      1
# 39770       21     16.0     NaN 2000-01-02  2000      1

# %%
lamean = la.groupby(['year','month']).mean()
lamean.plot(figsize=(15,8))

plt.xlabel("Year_Month")
plt.ylabel("Columbia Air Quality Index")
plt.title("Columbia AQI By Year_Month")


plt.savefig("ImagesQ11/Columbia AQI By Year_Mont.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
wy = df[df.State=='Kansas'][["NO2 AQI","SO2 AQI","CO AQI","Date Local","year","month"
                   ]]
wy.head()
# Out:
#        NO2 AQI  SO2 AQI  CO AQI Date Local  year  month
# 46130        8      6.0     NaN 2000-01-01  2000      1
# 46131        8      6.0    10.0 2000-01-01  2000      1
# 46132        8      NaN     NaN 2000-01-01  2000      1
# 46133        8      NaN    10.0 2000-01-01  2000      1
# 46134        6      4.0     NaN 2000-01-02  2000      1

# %%
wymean = wy.groupby(['year','month']).mean()
wymean.plot(figsize=(15,8))

plt.xlabel("Year_Month")
plt.ylabel("Kansas Air Quality Index")
plt.title("Kansas AQI By Year_Month")


plt.savefig("ImagesQ11/Kansas AQI By Year_Mont.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
us = df[["NO2 AQI","SO2 AQI","CO AQI","O3 AQI","Date Local","year","month"
                   ]]
us.head()
# Out:
#    NO2 AQI  SO2 AQI  CO AQI  O3 AQI Date Local  year  month
# 0       46     13.0     NaN      34 2000-01-01  2000      1
# 1       46     13.0    25.0      34 2000-01-01  2000      1
# 2       46      NaN     NaN      34 2000-01-01  2000      1
# 3       46      NaN    25.0      34 2000-01-01  2000      1
# 4       34      4.0     NaN      27 2000-01-02  2000      1

# %%
usmean = us.groupby(['year','month']).mean()
usmean.plot(figsize = (15,8))

plt.xlabel("Year_Month")
plt.ylabel("US Air Quality Index")
plt.title("US AQI By Year_Month")


plt.savefig("ImagesQ11/US AQI By Year_Mont.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
cal = df[df.State=='California'][["NO2 AQI","SO2 AQI","CO AQI" ,"O3 AQI","Date Local","year","month"
                   ]]
cal.head()
# Out:
#       NO2 AQI  SO2 AQI  CO AQI  O3 AQI Date Local  year  month
# 3516       25      3.0     NaN      25 2000-01-01  2000      1
# 3517       25      3.0     9.0      25 2000-01-01  2000      1
# 3518       25      NaN     NaN      25 2000-01-01  2000      1
# 3519       25      NaN     9.0      25 2000-01-01  2000      1
# 3520       28      3.0     NaN      27 2000-01-02  2000      1

# %%
calmean = cal.groupby(['year','month']).mean()
calmean.plot(figsize=(15,8))

plt.xlabel("Year_Month")
plt.ylabel("California Air Quality Index")
plt.title("California AQI By Year_Month")


plt.savefig("ImagesQ11/California AQI By Year_Mont.png" , bbox_inches="tight")
plt.tight_layout()
plt.show()
